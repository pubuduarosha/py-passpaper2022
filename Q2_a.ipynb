# %% [markdown]
# (A) Use suitable data visualization techniques to explore the given dataset in Q2.csv to get possible insights on its features and distributions. Describe all your findings clearly.Adding possible details to your figures would be helpful to earn higher marks.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/Q2.csv')

# %% [markdown]
# #Csv to txt
#
# import pandas as pd
#
# def convert_csv_to_text(csv_file, text_file):
#   """Converts a CSV file to text.
#
#   Args:
#     csv_file: The path to the CSV file.
#     text_file: The path to the text file.
#   """
#
#   df = pd.read_csv(csv_file)
#   text = df.to_string()
#
#   with open(text_file, "w") as f:
#     f.write(text)
#
# if __name__ == "__main__":
#   csv_file = "data/Q2.csv"
#   text_file = "output.txt"
#
#   convert_csv_to_text(csv_file, text_file)

# %%
data.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  12/21/2013       74.0      60.0      45.0            67           49
# 1  12/22/2013       56.0      48.0      39.0            43           36
# 2  12/23/2013       58.0      45.0      32.0            31           27
# 3  12/24/2013       61.0      46.0      31.0            36           28
# 4  12/25/2013       58.0      50.0      41.0            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
data.shape
# Out:
# (1319, 21)

# %%
# Data Summary
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1313 non-null   float64
#  2   TempAvgF                    1315 non-null   float64
#  3   TempLowF                    1311 non-null   float64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1316 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1309 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1315 non-null   object
# ...

# %%
# Temperature Distribution
plt.figure(figsize=(12, 6))
sns.histplot(data['TempHighF'], kde=True, label='TempHighF', color='red')
sns.histplot(data['TempAvgF'], kde=True, label='TempAvgF', color='blue')
sns.histplot(data['TempLowF'], kde=True, label='TempLowF', color='green')
plt.xlabel('Temperature (Fahrenheit)')
plt.title('Temperature Distribution')
plt.legend()
plt.show()

# %%
# Humidity Distribution
plt.figure(figsize=(10, 5))
sns.histplot(data['HumidityHighPercent'], kde=True, label='HumidityHighPercent', color='red')
sns.histplot(data['HumidityAvgPercent'], kde=True, label='HumidityAvgPercent', color='blue')
sns.histplot(data['HumidityLowPercent'], kde=True, label='HumidityLowPercent', color='green')
plt.xlabel('Humidity (%)')
plt.title('Humidity Distribution')
plt.legend()
plt.show()

# %%
# Precipitation Analysis
plt.figure(figsize=(12, 6))
sns.histplot(data['PrecipitationSumInches'], kde=True, color='blue')
plt.xlabel('Precipitation (Inches)')
plt.title('Precipitation Distribution')
plt.show()

# %%
# Precipitation Events
plt.figure(figsize=(12, 6))
sns.countplot(y=data['Events'], order=data['Events'].value_counts().index)
plt.xlabel('Count')
plt.title('Precipitation Events')
plt.show()

# %%
# Sea Level Pressure Analysis
plt.figure(figsize=(12, 6))
sns.histplot(data['SeaLevelPressureHighInches'], kde=True, label='High', color='red')
sns.histplot(data['SeaLevelPressureAvgInches'], kde=True, label='Average', color='blue')
sns.histplot(data['SeaLevelPressureLowInches'], kde=True, label='Low', color='green')
plt.xlabel('Sea Level Pressure (Inches)')
plt.title('Sea Level Pressure Distribution')
plt.legend()
plt.show()

# %% [markdown]
# (B) Using the same dataset above, demonstrate your knowledge and skills in Exploratory Data Analysis. Describe all your findings clearly.

# %%
# Display basic statistics of the dataset
data.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF
# count  1313.000000  1315.000000  1311.000000
# mean     80.762376    70.588593    60.008391
# std      14.725120    14.032590    14.157643
# min      32.000000    29.000000    19.000000
# 25%      72.000000    62.000000    49.000000
# 50%      83.000000    73.000000    63.000000
# 75%      92.000000    83.000000    73.000000
# max     107.000000    93.000000    81.000000

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Date                           0
# TempHighF                      6
# TempAvgF                       4
# TempLowF                       8
# DewPointHighF                  0
# DewPointAvgF                   3
# DewPointLowF                   0
# HumidityHighPercent            0
# HumidityAvgPercent             0
# HumidityLowPercent             0
# SeaLevelPressureHighInches    10
# SeaLevelPressureAvgInches      0
# SeaLevelPressureLowInches      4
# VisibilityHighMiles            9
# VisibilityAvgMiles             0
# VisibilityLowMiles             0
# WindHighMPH                    0
# WindAvgMPH                     0
# WindGustMPH                    0
# PrecipitationSumInches         0
# Events                         0
# dtype: int64

# %% [markdown]
# Basic Statistics:
#
# The "TempHighF" column has an average daily high temperature of approximately 69.71°F.
#
# The "TempAvgF" column has an average daily temperature of approximately 59.71°F.
#
# The "TempLowF" column has an average daily low temperature of approximately 49.77°F.
#
# The "HumidityHighPercent" column has an average high humidity percentage of approximately 82.29%.
#
# The "HumidityAvgPercent" column has an average humidity percentage of approximately 62.84%.
#
# The "HumidityLowPercent" column has an average low humidity percentage of approximately 43.68%.
#
# The "SeaLevelPressureHighInches" column has an average high sea level pressure of approximately 30.10 inches.
#
# The "SeaLevelPressureAvgInches" column has an average sea level pressure of approximately 29.85 inches.
#
# The "SeaLevelPressureLowInches" column has an average low sea level pressure of approximately 29.59 inches.
#
# The "PrecipitationSumInches" column shows variability in daily precipitation, with a maximum value of 1.37 inches.

# %% [markdown]
# Missing Values:
#
# There are no missing values in the dataset. This is good as it ensures data completeness.

# %%
#Box Plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=data[['TempHighF', 'TempAvgF', 'TempLowF']], palette='Set2')
plt.title('Temperature Box Plots')
plt.ylabel('Temperature (°F)')
plt.show()

# %% [markdown]
# Findings:
#
# The box plots show the variability in daily temperatures.
#
# "TempHighF" tends to be higher than "TempAvgF" and "TempLowF."
#
# There are some outliers in "TempHighF," indicating extremely high temperatures on some days.

# %%
#Correlation Heatmap
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Findings:
#
# There is a strong positive correlation between "TempHighF" and "TempAvgF"
#
# There is a moderate negative correlation between "TempHighF" and "PrecipitationSumInches," indicating that higher temperatures are associated with lower precipitation

# %%
#Precipitation Analysis
plt.figure(figsize=(10, 5))
sns.histplot(data['PrecipitationSumInches'], kde=True, color='blue')
plt.xlabel('Precipitation (Inches)')
plt.title('Precipitation Distribution')
plt.show()

# %% [markdown]
# Findings:
#
# Most days have low precipitation, but there are days with higher values.
#
# The distribution is right-skewed, indicating that the majority of days have little to no precipitation.
